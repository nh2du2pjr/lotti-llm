# %%
# !git clone https://github.com/nh2du2pjr/lotti-llm.git
# %cd lotti-llm
# !pip install -e .

# %%
import torch
print('torch', torch.__version__)
print('cuda available', torch.cuda.is_available())
if torch.cuda.is_available():
    print('device', torch.cuda.get_device_name(0))
